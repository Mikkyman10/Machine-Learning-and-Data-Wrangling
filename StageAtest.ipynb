# %%
# created by student ID: 1486657558c1f000
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
Food_n_agric = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding="iso-8859-1")

# %%
Food_n_agric.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %% [markdown]
# Question 11. What is the total sum of Animal Fat produced in 2014 and 2017 respectively?

# %%
Food_n_agric.groupby("Item")["Y2014", "Y2017"].sum()
# Out:
#                               Y2014      Y2017
# Item
# Alcohol, Non-Food           2403.00    2348.00
# Alcoholic Beverages       102410.11   95581.06
# Animal Products            11935.65   11547.65
# Animal fats               209460.54  269617.53
# Apples and products         9499.23   10198.90
# Aquatic Animals, Others       14.55       5.92
# Aquatic Plants               507.29     452.02
# Aquatic Products, Other      519.62     456.65
# Bananas                    53267.31   53008.82
# Barley and products        25384.66   26176.98
# Beans                      19207.68   21351.42
# Beer                       41879.92   41962.92
# Beverages, Alcoholic        3067.16    3115.24
# Beverages, Fermented       50536.78   43958.75
# Bovine Meat                22098.60   22612.86
# Butter, Ghee                1249.29    1116.68
# Cassava and products      405442.57  401440.17
# Cephalopods                  423.03     532.14
# Cereals - Excluding Beer  851924.06  905221.25
# ...

# %% [markdown]
# Question 12. What is the mean and standard deviation across the whole dataset for the year 2015 to 3 decimal places?

# %%
Food_n_agric.describe()["Y2015"]
# Out:
# count     59395.000000
# mean        135.235966
# std        1603.403984
# min       -3161.000000
# 25%           0.000000
# 50%           0.080000
# 75%           8.460000
# max      181137.000000
# Name: Y2015, dtype: float64

# %% [markdown]
# Question 13. What is the total number and percentage of missing data in 2016 to 2 decimal places?

# %%
Food_n_agric.isnull().sum()["Y2016"]
# Out:
# 1535

# %%
Food_n_agric["Y2016"].shape
# Out:
# (60943,)

# %%
percentage_null = 1535 / 60943 * 100
print(percentage_null)
# Out:
# 2.5187470259094566

# %% [markdown]
# Question 14. Which year had the highest correlation with ‘Element Code’?

# %%
Food_n_agric.corr()["Element Code"].sort_values()
# Out:
# Item Code      -0.024683
# Area Code      -0.000209
# Y2016           0.023444
# Y2015           0.023889
# Y2017           0.024254
# Y2018           0.024279
# Y2014           0.024457
# Element Code    1.000000
# Name: Element Code, dtype: float64

# %%
Question 17
# Out:
# 17.0

# %%
Food_n_agric.groupby("Element")["Y2018"].sum().sort_values()
# Out:
# Element
# Tourist consumption                            90.00
# Fat supply quantity (g/capita/day)          10258.69
# Protein supply quantity (g/capita/day)      11833.56
# Stock Variation                             20577.91
# Seed                                        25263.14
# Residuals                                   34864.00
# Food supply quantity (kg/capita/yr)         49056.85
# Other uses (non-food)                       91300.97
# Losses                                     163902.00
# Export Quantity                            181594.80
# Feed                                       233489.68
# Import Quantity                            287997.09
# Processing                                 308429.00
# Food supply (kcal/capita/day)              455261.00
# Total Population - Both sexes             1140605.00
# Food                                      1303841.28
# Production                                2075072.89
# Domestic supply quantity                  2161192.10
# ...

# %%
Food_n_agric.groupby(['Element', 'Area'])['Y2018'].aggregate('sum').unstack()
# Out:
# Area                                     Algeria    Angola     Benin  \
# Element
# Domestic supply quantity                90023.42  59590.22  31447.90
# Export Quantity                           811.54   7962.28    729.44
# Fat supply quantity (g/capita/day)        309.09    230.90    207.82
# Feed                                    10668.00   7859.66   4662.54
# Food                                    63736.33  37256.56  16209.34
# Food supply (kcal/capita/day)           13288.00   9538.00  11023.00
# Food supply quantity (kg/capita/yr)      1509.28   1209.36   1411.42
# Import Quantity                         36238.29   7769.67   7008.24
# Losses                                   7708.00   6135.00   2814.00
# Other uses (non-food)                    3970.08   1014.00   4192.00
# Processing                               2479.00   6727.00   2148.00
# Production                              60766.67  59039.83  27500.54
# ...

# %% [markdown]
# Question 20. What is the total number of unique countries in the dataset?

# %%
len(Food_n_agric["Area"].unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7c7be2b95a50> in <module>()
# ----> 1 len(Food_n_agric["Area"].unique())
#
# NameError: name 'Food_n_agric' is not defined
